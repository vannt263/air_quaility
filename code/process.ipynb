# %%
import numpy as np
import pandas as pd
pd.DataFrame(np.random.randint(150,311 ,89)).to_csv("D:/study/Data_visualize/CK/air_quality/code/test1.csv")

# %%
import os

# %%
files = os.listdir("../fix data")

# %%
required_columns = ['pm25', 'pm10', 'o3', 'no2', 'so2', 'co', 'aqi']

# %%
def phan_loai_aqi(aqi):
    if 0 <= aqi <= 50:
        return 'Tốt'
    elif 51 <= aqi <= 100:
        return 'Vừa Phải'
    elif 101 <= aqi <= 150:
        return 'Không tốt cho người nhạy cảm'
    elif 151 <= aqi <= 200:
        return 'Không tốt'
    elif 201 <= aqi <= 300:
        return 'Rất không tốt'
    else:
        return 'Nguy hiểm'

# %%
df = pd.read_csv("D:/study/Data_visualize/CK/air_quality/data/Ba Đình - Hà Nội.csv")
df = df.drop(['Unnamed: 0'], axis=1)
# Chuyển cột 'date' sang định dạng datetime
df
# Out:
#      địa điểm trạm đo        date  pm25  pm10  o3  no2  so2  co  aqi  \
# 0             Ba Đình  2014-01-01   236     0   0   40    6  28  236
# 1             Ba Đình  2014-01-02   292     0  22   39    8  43  292
# 2             Ba Đình  2014-01-03   256     0  69   25   12  28  256
# 3             Ba Đình  2014-01-04   278     0  24    0    0   0  278
# 4             Ba Đình  2014-01-05   189     0   0   35    5  33  189
# ...               ...         ...   ...   ...  ..  ...  ...  ..  ...
# 3518          Ba Đình  2023-10-15    88     0   9   12   10   0   88
# 3519          Ba Đình  2023-10-16   136     0  14   13   10   0  136
# 3520          Ba Đình  2023-10-17   148     0   9   15   10   0  148
# 3521          Ba Đình  2023-10-18   153     0   2   15   11   0  153
# 3522          Ba Đình  2023-10-19   188     0   0    0    0   0  188
#
#                     mức độ ô nhiễm
# 0                    Rất không tốt
# 1                    Rất không tốt
# 2                    Rất không tốt
# 3                    Rất không tốt
# 4                        Không tốt
# ...                            ...
# 3518                      Vừa Phải
# 3519  Không tốt cho người nhạy cảm
# 3520  Không tốt cho người nhạy cảm
# 3521                     Không tốt
# 3522                     Không tốt
#
# [3523 rows x 10 columns]
