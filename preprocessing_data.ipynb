# %%
import pandas as pd
import numpy as np
import os

# %%
files = os.listdir("../data")

# %%
required_columns = ['pm25', 'pm10', 'o3', 'no2', 'so2', 'co', 'aqi']

# %%
for file in files:
    data = pd.read_csv(f"../data/{file}")

    # đọc dữ liệu và reset lại index
    data['date'] = pd.to_datetime(data['date'])
    data = data.sort_values(by='date', ascending=True)
    data = data.reset_index(drop=True)
    
    data = data.rename(columns=lambda x: x.strip()) # sửa tên cột

    data[data.columns[1:]] = data[data.columns[1:]].replace(' ', 0) #ép kiểu cột sang int
    data[data.columns[1:]] = data[data.columns[1:]].astype(int)

    for column in required_columns:
        if column not in data.columns:
            data[column] = 0 # Thêm cột mới với giá trị None hoặc 0 (tùy ý)

    # Đảm bảo thứ tự các cột là 'pm25', 'pm10', 'o3', 'no2', 'so2', 'co', 'aqi'
    data = data[['date', 'pm25', 'pm10', 'o3', 'no2', 'so2', 'co', 'aqi']]

    # Kiểm tra và gán lại giá trị của 'aqi'
    data['aqi'] = data[data.columns[1:]].max(axis=1)
    data.insert(0, "địa điểm trạm đo", file.split("-")[0].strip())
    data.to_csv(f"../data/{file}")
# Out:
# C:\Users\vannt\AppData\Local\Temp\ipykernel_20280\3631063046.py:5: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data['date'] = pd.to_datetime(data['date'])

# %%
for file in files:
    df = pd.read_csv(f"../data/{file}")
    df = df.drop(['Unnamed: 0.1', 'Unnamed: 0'], axis=1)
    condition = (df[['pm25', 'pm10', 'o3', 'no2', 'so2', 'co']].sum(axis=1) == 0) & (df['aqi'] != 0)
    df.loc[condition, 'pm25'] = df['aqi']
    df.to_csv(f"../data/{file}")

# %%
import pandas as pd
df =pd.read_csv("D:/study/Data_visualize/CK/air_quality/data/Ba Đình - Hà Nội.csv")
df = df.drop(['Unnamed: 0'], axis=1)
df
# Out:
#      địa điểm trạm đo        date  pm25  pm10  o3  no2  so2  co  aqi  \
# 0             Ba Đình   1/01/2014   236     0   0   40    6  28  236
# 1             Ba Đình   2/01/2014   292     0  22   39    8  43  292
# 2             Ba Đình   3/01/2014   256     0  69   25   12  28  256
# 3             Ba Đình   4/01/2014   278     0  24    0    0   0  278
# 4             Ba Đình   5/01/2014   189     0   0   35    5  33  189
# ...               ...         ...   ...   ...  ..  ...  ...  ..  ...
# 3518          Ba Đình  15/10/2023    88     0   9   12   10   0   88
# 3519          Ba Đình  16/10/2023   136     0  14   13   10   0  136
# 3520          Ba Đình  17/10/2023   148     0   9   15   10   0  148
# 3521          Ba Đình  18/10/2023   153     0   2   15   11   0  153
# 3522          Ba Đình  19/10/2023   188     0   0    0    0   0  188
#
#                     mức độ ô nhiễm
# 0                              Tốt
# 1                              Tốt
# ...

# %%
import pandas as pd


def phan_loai_aqi(aqi):
    if 0 <= aqi <= 50:
        return 'Tốt'
    elif 51 <= aqi <= 100:
        return 'Vừa Phải'
    elif 101 <= aqi <= 150:
        return 'Không tốt cho người nhạy cảm'
    elif 151 <= aqi <= 200:
        return 'Không tốt'
    elif 201 <= aqi <= 300:
        return 'Rất không tốt'
    else:
        return 'Nguy hiểm'

# Áp dụng hàm phan_loai_aqi cho cột 'aqi' trong DataFrame
df['mức độ ô nhiễm'] = df['aqi'].apply(phan_loai_aqi)

# Hiển thị DataFrame sau khi thêm cột 'muc_do_o_nhiem'
df.to_csv("D:/study/Data_visualize/CK/air_quality/data/Ba Đình - Hà Nội.csv")

# %%
import numpy as np
import pandas as pd

# Giả sử df là DataFrame của bạn
# df['so2'] có giá trị là 107

# Lấy index của các hàng có giá trị 'so2' là 107
indexes = data[data['so2'] == 186].index

# Kiểm tra điều kiện và thay đổi giá trị nếu cần
if (data['so2'] == 186).any():
    # Tạo một số nguyên ngẫu nhiên trong khoảng từ 100 đến 250
    new_value = np.random.randint(100, 251, 97)

    # Thay đổi giá trị của cột 'so2' thành giá trị mới cho các hàng có chỉ số indexes
    data.loc[indexes, 'so2'] = new_value
data
# Out:
#      địa điểm trạm đo        date  pm25  pm10  o3  no2  so2  co  aqi  \
# 0             Hạ Long  2014-08-02     0    18   8    0   12   8   18
# 1             Hạ Long  2014-08-03     0    28  90    0   11  21   90
# 2             Hạ Long  2014-08-04     0    23  85    0   28  22   85
# 3             Hạ Long  2014-08-05     0    22  42    0   23  21   42
# 4             Hạ Long  2014-08-06     0    20  42    0   23  22   42
# ...               ...         ...   ...   ...  ..  ...  ...  ..  ...
# 1849          Hạ Long  2023-10-15    45    28  31   19    0   0   45
# 1850          Hạ Long  2023-10-16    54    34  42   26    0   0   54
# 1851          Hạ Long  2023-10-17    59    28  23   22    0   0   59
# 1852          Hạ Long  2023-10-18    52    15  18   10    0   0   52
# 1853          Hạ Long  2023-10-19    30     0   0    0    0   0   30
#
#      mức độ ô nhiễm
# 0               Tốt
# 1          Vừa Phải
# 2          Vừa Phải
# 3               Tốt
# 4               Tốt
# ...

# %%
id= data[data['aqi'] == 500].index
id
# Out:
# Index([219, 220, 221, 222, 223, 224, 225, 226, 227, 228, 229, 230, 231, 232,
#        233, 234, 235, 236, 237, 238, 239, 240, 241, 242, 243, 244, 245, 246,
#        247, 248, 249, 250, 251, 252, 253, 254, 255, 256, 257, 258, 259, 260,
#        261, 262, 263, 264, 265, 266, 267, 268, 269, 270, 271, 272, 273, 274,
#        275, 276, 277, 278, 279, 280, 281, 282, 283, 284, 285, 286, 287, 288,
#        289, 290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302,
#        303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315],
#       dtype='int64')

# %%
print(data.dtypes)
# Out:
# địa điểm trạm đo    object
# date                object
# pm25                 int64
# pm10                 int64
# o3                   int64
# no2                  int64
# so2                  int64
# co                   int64
# aqi                  int64
# mức độ ô nhiễm      object
# dtype: object

# %%
data.columns[2:-2]
# Out:
# Index(['pm25', 'pm10', 'o3', 'no2', 'so2', 'co'], dtype='object')

# %%
data['aqi'] = data[data.columns[2:-2]].max(axis=1)

# %%
data[219:315]
# Out:
#     địa điểm trạm đo        date  pm25  pm10  o3  no2  so2  co  aqi  \
# 219          Hạ Long  2018-09-09     0     0   0    0  161   0  161
# 220          Hạ Long  2018-09-10     0     0   0    0  188   0  188
# 221          Hạ Long  2018-09-11     0     0   0    0  157   0  157
# 222          Hạ Long  2018-09-12     0     0   0    0  115   0  115
# 223          Hạ Long  2018-09-13     0     0   0    0  134   0  134
# ..               ...         ...   ...   ...  ..  ...  ...  ..  ...
# 310          Hạ Long  2019-03-25     0     0   0    0  203   0  203
# 311          Hạ Long  2019-03-26     0     0   0    0  248   0  248
# 312          Hạ Long  2019-03-27     0     0   0    0  207   0  207
# 313          Hạ Long  2019-03-28     0     0   0    0  213   0  213
# 314          Hạ Long  2019-03-29     0     0   0    0  115   0  115
#
#     mức độ ô nhiễm
# 219      Nguy hiểm
# 220      Nguy hiểm
# 221      Nguy hiểm
# 222      Nguy hiểm
# 223      Nguy hiểm
# ..             ...
# ...

# %%
data.to_csv("D:/study/Data_visualize/CK/air_quality/data/Hạ Long - Quảng Ninh.csv")
