# %%
import pandas as pd
import numpy as np
import os

# %%
files = os.listdir("../data")

# %%
required_columns = ['pm25', 'pm10', 'o3', 'no2', 'so2', 'co', 'aqi']

# %%
for file in files:
    data = pd.read_csv(f"../data/{file}")

    # đọc dữ liệu và reset lại index
    data['date'] = pd.to_datetime(data['date'])
    data = data.sort_values(by='date', ascending=True)
    data = data.reset_index(drop=True)
    
    data = data.rename(columns=lambda x: x.strip()) # sửa tên cột

    data[data.columns[1:]] = data[data.columns[1:]].replace(' ', 0) #ép kiểu cột sang int
    data[data.columns[1:]] = data[data.columns[1:]].astype(int)

    for column in required_columns:
        if column not in data.columns:
            data[column] = 0 # Thêm cột mới với giá trị None hoặc 0 (tùy ý)

    # Đảm bảo thứ tự các cột là 'pm25', 'pm10', 'o3', 'no2', 'so2', 'co', 'aqi'
    data = data[['date', 'pm25', 'pm10', 'o3', 'no2', 'so2', 'co', 'aqi']]

    # Kiểm tra và gán lại giá trị của 'aqi'
    data['aqi'] = data[data.columns[1:]].max(axis=1)
    data.insert(0, "địa điểm trạm đo", file.split("-")[0].strip())
    data.to_csv(f"../data/{file}")
# Out:
# C:\Users\vannt\AppData\Local\Temp\ipykernel_20280\3631063046.py:5: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data['date'] = pd.to_datetime(data['date'])

# %%
for file in files:
    df = pd.read_csv(f"../data/{file}")
    df = df.drop(['Unnamed: 0.1', 'Unnamed: 0'], axis=1)
    condition = (df[['pm25', 'pm10', 'o3', 'no2', 'so2', 'co']].sum(axis=1) == 0) & (df['aqi'] != 0)
    df.loc[condition, 'pm25'] = df['aqi']
    df.to_csv(f"../data/{file}")

# %%
from pyvi import ViUtils

# %%
import pandas as pd

# %%
khuvuc = pd.read_csv("./Khu vực.csv")

# %%
for i in range(len(khuvuc)):
    khuvuc.at[i, "Tỉnh"] = ViUtils.remove_accents(khuvuc.at[i, "Tỉnh"]).decode('utf-8')

# %%
khuvuc
# Out:
#     Unnamed: 0  Địa điểm Trạm đo             Tỉnh   latitude   longitude  \
# 0            0     Phạm Văn Đồng           Ha Noi  21.051210  105.782320
# 1            1        Phú Thượng           Ha Noi  21.081100  105.818000
# 2            2           Mỹ Đình           Ha Noi  21.019940  105.770560
# 3            3       Bắc Từ Liêm           Ha Noi  21.049750  105.741870
# 4            4       Nam Từ Liêm           Ha Noi  21.005770  105.748420
# 5            5          Cầu Giấy           Ha Noi  21.015250  105.800130
# 6            6           Láng Hạ           Ha Noi  21.021506  105.818875
# 7            7           Đống Đa           Ha Noi  21.007200  105.835700
# 8            8         Hoàn Kiếm           Ha Noi  21.039820  105.847260
# 9            9         Hoàng Mai           Ha Noi  20.988320  105.854897
# 10          10           Ba Đình           Ha Noi  21.040370  105.841000
# 11          11           Bến Lức          Long An  10.702460  106.466890
# 12          12         Lương Tài         Bac Ninh  21.001500  106.174390
# 0     Đặc biệt
# 1     Đặc biệt
# 2     Đặc biệt
# 3     Đặc biệt
# 4     Đặc biệt
# 5     Đặc biệt
# 6     Đặc biệt
# 7     Đặc biệt
# 8     Đặc biệt
# 9     Đặc biệt
# 10    Đặc biệt
# 11     Loại IV
# 12      Loại V
# 13      Loại V
# 14      Loại I
# 15      Loại V
# 16      Loại I
# 17      Loại I
# 18      Loại I
# 19    Loại III
# 20      Loại V
# 21      Loại I
# 22      Loại I
# 23    Đặc biệt
# 24    Đặc biệt
# 25      Loại V
# 26      Loại I
# 27      Loại I
# 28      Loại V
# 29     Loại II
# 30      Loại I
# 31      Loại I
# 32     Loại IV
# 33      Loại I
# 34     Loại IV
# 35     Loại IV
# 36    Loại III
# 37     Loại IV
# 38     Loại IV
# 39      Loại V
# 40      Loại I
# 41    Đặc biệt
# 42     Loại IV
# 43      Loại I
# 44      Loại I
# 45     Loại IV
# 46    Loại III
# 47     Loại II
# 48     Loại IV
# 49    Loại III
# 50     Loại IV
# 51     Loại II
# 52      Loại I
# 53      Loại V
# 54      Loại I
# 55     Lọai IV
# 56      Loại I
# 57    Loại III

# %%
khuvuc = khuvuc.drop(['Unnamed: 0'], axis=1)

# %%
khuvuc.to_csv("./Khu vực.csv")

# %%
import pandas as pd

# %%
data_path = "./data/Bảo Thắng - Lào Cai.csv"

# %%
file = pd.read_csv(data_path)

# %%
file
# Out:
#      Unnamed: 0 địa điểm trạm đo        date  pm25  pm10  o3  no2  so2  co  \
# 0             0        Bảo Thắng    1/1/2022     0    31  17    8    1   3
# 1             1        Bảo Thắng    2/1/2022    39    38  20    7    2   3
# 2             2        Bảo Thắng    3/1/2022    51    50  24    8    2   3
# 3             3        Bảo Thắng    4/1/2022    73    62  19    9    8   4
# 4             4        Bảo Thắng    5/1/2022    99    59  18   10    2   3
# ..          ...              ...         ...   ...   ...  ..  ...  ...  ..
# 609         609        Bảo Thắng  15/10/2023    27    34  24    4    6   8
# 610         610        Bảo Thắng  16/10/2023    36    47  31    7   12   9
# 611         611        Bảo Thắng  17/10/2023    61    59  30    8   17  10
# 612         612        Bảo Thắng  18/10/2023    88    51   6    6    1   9
# 613         613        Bảo Thắng  19/10/2023    74     0   0    0    0   0
#
#      aqi mức độ ô nhiễm
# 0     31            Tốt
# 1     39            Tốt
# 2     51       Vừa Phải
# 3     73       Vừa Phải
# 4     99       Vừa Phải
# ..   ...            ...
# 609   34            Tốt
# 610   47            Tốt
# 611   61       Vừa Phải
# 612   88       Vừa Phải
# 613   74       Vừa Phải
#
# [614 rows x 11 columns]

# %%
file["date"] = pd.to_datetime(file['date'], format="%d/%m/%Y")

# %%
file["date"] = pd.to_datetime(file['date'])

# %%
for i in range(len(file)):
    file.at[i, "địa điểm trạm đo"] = "Yên Phong"

# %%
file.to_csv(data_path)
